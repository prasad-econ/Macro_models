# %%
#Value functoion iterations

import numpy as np
import matplotlib.pyplot as plt

# %%
beta = 0.95
alpha = 0.36
sigma = 2
delta = 0.1

# %%
#Utility Function
def utility(c):
    if sigma == 1:
        return np.log(c)
    else:
        return  (c**(1-sigma)-1)/(1-sigma)

# %%
# ==========================================================
# Steady State
# ==========================================================
k_ss = ((1/beta - (1-delta))/alpha)**(1/(alpha-1))
c_ss = k_ss**alpha - delta*k_ss

# %%
print("Steady State Capital =", k_ss)
print("Steady State Consumption =", c_ss)
# Out:
# Steady State Capital = 3.8218909152179132
# Steady State Consumption = 1.2382032555735218

# %%
#Grid 
Nk = 300

k_min = 0.25*k_ss
k_max = 1.75*k_ss

k_grid = np.linspace(k_min,k_max,Nk)

# %%
# ==========================================================
# Initial Guess
# ==========================================================

V = np.zeros(Nk)
policy = np.zeros(Nk)

tol = 1e-6
max_iter = 1000

# %%
for iteration in range(max_iter):

    V_new = np.zeros_like(V)

    policy_new = np.zeros_like(policy)

    for i,k in enumerate(k_grid):

        value_max = -1e10

        best_kprime = k_grid[0]

        # Candidate next-period capital
        for kp in k_grid:

            # Consumption implied by budget constraint
            c = k**alpha + (1-delta)*k - kp

            if c <= 0:
                continue

            # Continuation value using interpolation
            continuation = np.interp(kp,k_grid,V)

            value = utility(c) + beta*continuation

            if value > value_max:

                value_max = value
                best_kprime = kp

        V_new[i] = value_max
        policy_new[i] = best_kprime

    diff = np.max(np.abs(V_new-V))

    print(f"Iteration {iteration:3d}   Error = {diff:.8f}")

    V = V_new.copy()
    policy = policy_new.copy()

    if diff < tol:
        print("Converged!")
        break
# Out:
# Iteration   0   Error = 0.85807655
# Iteration   1   Error = 0.62125784
# Iteration   2   Error = 0.47303094
# Iteration   3   Error = 0.37380510
# Iteration   4   Error = 0.30400552
# Iteration   5   Error = 0.25293134
# Iteration   6   Error = 0.21438929
# Iteration   7   Error = 0.18446158
# Iteration   8   Error = 0.16074737
# Iteration   9   Error = 0.14156001
# Iteration  10   Error = 0.12577240
# Iteration  11   Error = 0.11257472
# Iteration  12   Error = 0.10142242
# Iteration  13   Error = 0.09197202
# Iteration  14   Error = 0.08370556
# Iteration  15   Error = 0.07657032
# Iteration  16   Error = 0.07025597
# Iteration  17   Error = 0.06471276
# Iteration  18   Error = 0.05982342
# Iteration  19   Error = 0.05533975
# Iteration  20   Error = 0.05139931
# Iteration  21   Error = 0.04790039
# Iteration  22   Error = 0.04448545
# Iteration  23   Error = 0.04161100
# Iteration  24   Error = 0.03896161
# Iteration  25   Error = 0.03648578
# Iteration  26   Error = 0.03411629
# Iteration  27   Error = 0.03207651
# Iteration  28   Error = 0.03010218
# Iteration  29   Error = 0.02839434
# Iteration  30   Error = 0.02673057
# Iteration  31   Error = 0.02508060
# Iteration  32   Error = 0.02374166
# Iteration  33   Error = 0.02241812
# Iteration  34   Error = 0.02114356
# Iteration  35   Error = 0.01992756
# Iteration  36   Error = 0.01886251
# Iteration  37   Error = 0.01786778
# Iteration  38   Error = 0.01688816
# Iteration  39   Error = 0.01595741
# Iteration  40   Error = 0.01508525
# Iteration  41   Error = 0.01430406
# Iteration  42   Error = 0.01357364
# Iteration  43   Error = 0.01286592
# Iteration  44   Error = 0.01218769
# Iteration  45   Error = 0.01154004
# Iteration  46   Error = 0.01093913
# Iteration  47   Error = 0.01035919
# Iteration  48   Error = 0.00981587
# Iteration  49   Error = 0.00932387
# Iteration  50   Error = 0.00885423
# Iteration  51   Error = 0.00840901
# Iteration  52   Error = 0.00798248
# Iteration  53   Error = 0.00758088
# Iteration  54   Error = 0.00719516
# Iteration  55   Error = 0.00682592
# Iteration  56   Error = 0.00648279
# Iteration  57   Error = 0.00614964
# Iteration  58   Error = 0.00583364
# Iteration  59   Error = 0.00554125
# Iteration  60   Error = 0.00525053
# Iteration  61   Error = 0.00497971
# Iteration  62   Error = 0.00473025
# Iteration  63   Error = 0.00449280
# Iteration  64   Error = 0.00426816
# Iteration  65   Error = 0.00405476
# Iteration  66   Error = 0.00385202
# Iteration  67   Error = 0.00365942
# Iteration  68   Error = 0.00347645
# Iteration  69   Error = 0.00330262
# Iteration  70   Error = 0.00313749
# Iteration  71   Error = 0.00298062
# Iteration  72   Error = 0.00283159
# Iteration  73   Error = 0.00269001
# Iteration  74   Error = 0.00255551
# Iteration  75   Error = 0.00242773
# Iteration  76   Error = 0.00230635
# Iteration  77   Error = 0.00219103
# Iteration  78   Error = 0.00208148
# Iteration  79   Error = 0.00197740
# Iteration  80   Error = 0.00187853
# Iteration  81   Error = 0.00178461
# Iteration  82   Error = 0.00169538
# Iteration  83   Error = 0.00161061
# Iteration  84   Error = 0.00153008
# Iteration  85   Error = 0.00145357
# Iteration  86   Error = 0.00138089
# Iteration  87   Error = 0.00131185
# Iteration  88   Error = 0.00124626
# Iteration  89   Error = 0.00118394
# Iteration  90   Error = 0.00112475
# Iteration  91   Error = 0.00106851
# Iteration  92   Error = 0.00101508
# Iteration  93   Error = 0.00096433
# Iteration  94   Error = 0.00091611
# Iteration  95   Error = 0.00087031
# Iteration  96   Error = 0.00082679
# Iteration  97   Error = 0.00078545
# Iteration  98   Error = 0.00074618
# Iteration  99   Error = 0.00070887
# Iteration 100   Error = 0.00067343
# Iteration 101   Error = 0.00063976
# Iteration 102   Error = 0.00060777
# Iteration 103   Error = 0.00057738
# Iteration 104   Error = 0.00054851
# Iteration 105   Error = 0.00052109
# Iteration 106   Error = 0.00049503
# Iteration 107   Error = 0.00047028
# Iteration 108   Error = 0.00044677
# Iteration 109   Error = 0.00042443
# Iteration 110   Error = 0.00040321
# Iteration 111   Error = 0.00038305
# Iteration 112   Error = 0.00036389
# Iteration 113   Error = 0.00034570
# Iteration 114   Error = 0.00032841
# Iteration 115   Error = 0.00031199
# Iteration 116   Error = 0.00029639
# Iteration 117   Error = 0.00028157
# Iteration 118   Error = 0.00026750
# Iteration 119   Error = 0.00025412
# Iteration 120   Error = 0.00024141
# Iteration 121   Error = 0.00022934
# Iteration 122   Error = 0.00021788
# Iteration 123   Error = 0.00020698
# Iteration 124   Error = 0.00019663
# Iteration 125   Error = 0.00018680
# Iteration 126   Error = 0.00017746
# Iteration 127   Error = 0.00016859
# Iteration 128   Error = 0.00016016
# Iteration 129   Error = 0.00015215
# Iteration 130   Error = 0.00014454
# Iteration 131   Error = 0.00013732
# Iteration 132   Error = 0.00013045
# Iteration 133   Error = 0.00012393
# Iteration 134   Error = 0.00011773
# Iteration 135   Error = 0.00011185
# Iteration 136   Error = 0.00010625
# Iteration 137   Error = 0.00010094
# Iteration 138   Error = 0.00009589
# Iteration 139   Error = 0.00009110
# Iteration 140   Error = 0.00008654
# Iteration 141   Error = 0.00008222
# Iteration 142   Error = 0.00007811
# Iteration 143   Error = 0.00007420
# Iteration 144   Error = 0.00007049
# Iteration 145   Error = 0.00006697
# Iteration 146   Error = 0.00006362
# Iteration 147   Error = 0.00006044
# Iteration 148   Error = 0.00005741
# Iteration 149   Error = 0.00005454
# Iteration 150   Error = 0.00005182
# Iteration 151   Error = 0.00004923
# Iteration 152   Error = 0.00004676
# Iteration 153   Error = 0.00004443
# Iteration 154   Error = 0.00004221
# Iteration 155   Error = 0.00004009
# Iteration 156   Error = 0.00003809
# Iteration 157   Error = 0.00003619
# Iteration 158   Error = 0.00003438
# Iteration 159   Error = 0.00003266
# Iteration 160   Error = 0.00003102
# Iteration 161   Error = 0.00002947
# Iteration 162   Error = 0.00002800
# Iteration 163   Error = 0.00002660
# Iteration 164   Error = 0.00002527
# Iteration 165   Error = 0.00002401
# Iteration 166   Error = 0.00002281
# Iteration 167   Error = 0.00002167
# Iteration 168   Error = 0.00002058
# Iteration 169   Error = 0.00001955
# Iteration 170   Error = 0.00001858
# Iteration 171   Error = 0.00001765
# Iteration 172   Error = 0.00001676
# Iteration 173   Error = 0.00001593
# Iteration 174   Error = 0.00001513
# Iteration 175   Error = 0.00001437
# Iteration 176   Error = 0.00001365
# Iteration 177   Error = 0.00001297
# Iteration 178   Error = 0.00001232
# Iteration 179   Error = 0.00001171
# Iteration 180   Error = 0.00001112
# Iteration 181   Error = 0.00001057
# Iteration 182   Error = 0.00001004
# Iteration 183   Error = 0.00000954
# Iteration 184   Error = 0.00000906
# Iteration 185   Error = 0.00000861
# Iteration 186   Error = 0.00000818
# Iteration 187   Error = 0.00000777
# Iteration 188   Error = 0.00000738
# Iteration 189   Error = 0.00000701
# Iteration 190   Error = 0.00000666
# Iteration 191   Error = 0.00000633
# Iteration 192   Error = 0.00000601
# Iteration 193   Error = 0.00000571
# Iteration 194   Error = 0.00000542
# Iteration 195   Error = 0.00000515
# Iteration 196   Error = 0.00000490
# Iteration 197   Error = 0.00000465
# Iteration 198   Error = 0.00000442
# Iteration 199   Error = 0.00000420
# Iteration 200   Error = 0.00000399
# Iteration 201   Error = 0.00000379
# Iteration 202   Error = 0.00000360
# Iteration 203   Error = 0.00000342
# Iteration 204   Error = 0.00000325
# Iteration 205   Error = 0.00000309
# Iteration 206   Error = 0.00000293
# Iteration 207   Error = 0.00000278
# Iteration 208   Error = 0.00000265
# Iteration 209   Error = 0.00000251
# Iteration 210   Error = 0.00000239
# Iteration 211   Error = 0.00000227
# Iteration 212   Error = 0.00000215
# Iteration 213   Error = 0.00000205
# Iteration 214   Error = 0.00000194
# Iteration 215   Error = 0.00000185
# Iteration 216   Error = 0.00000175
# Iteration 217   Error = 0.00000167
# Iteration 218   Error = 0.00000158
# Iteration 219   Error = 0.00000150
# Iteration 220   Error = 0.00000143
# Iteration 221   Error = 0.00000136
# Iteration 222   Error = 0.00000129
# Iteration 223   Error = 0.00000123
# Iteration 224   Error = 0.00000116
# Iteration 225   Error = 0.00000111
# Iteration 226   Error = 0.00000105
# Iteration 227   Error = 0.00000100
# Converged!

# %%
# ==========================================================
# Policy Consumption
# ==========================================================

consumption_policy = (
    k_grid**alpha
    +(1-delta)*k_grid
    -policy
)

# %%
# ==========================================================
# Policy Consumption
# ==========================================================

consumption_policy = (
    k_grid**alpha
    +(1-delta)*k_grid
    -policy
)

plt.figure(figsize=(8,5))
plt.plot(k_grid,policy)
plt.plot(k_grid,k_grid,'--')
plt.xlabel("Current Capital")
plt.ylabel("Next Period Capital")
plt.title("Policy Function")
plt.grid()
plt.show()

plt.figure(figsize=(8,5))
plt.plot(k_grid,consumption_policy)
plt.xlabel("Current Capital")
plt.ylabel("Consumption")
plt.title("Consumption Policy")
plt.grid()
plt.show()

# %%
V = np.zeros(len(a_grid))

# %%
policy = np.zeros(len(a_grid))

# %%
tol = 1e-6

# %%
error = 1
